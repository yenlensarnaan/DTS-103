# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlensarnaan/DTS-103/blob/main/WEEK_7_Basic_Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 ASSIGNMENT (Week 7)
#
# 1. Create dataset with at least 10 students and 3 subjects.
# 2. Create line, bar, and pie charts.
# 3. Add titles and axis labels.
# 4. Write short interpretation.
#
# Submit your completed notebook (.ipynb).

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

data = {
"students": ["Ayo", "Bola", "chidi", "David", "Ela", "Femi", "Grace", "Hassan", "Evy", "John"],
"math_scores": [70, 85, 60, 90, 75, 80, 68, 88, 72, 78],
"english_scores": [68, 80, 58, 85, 70, 78, 60, 85, 74, 76],
"science_scores": [75, 88, 62, 92, 78, 85, 70, 90, 76, 80],
}

df = pd.DataFrame(data)
df
# Out:
#   students  math_scores  english_scores  science_scores
# 0      Ayo           70              68              75
# 1     Bola           85              80              88
# 2    chidi           60              58              62
# 3    David           90              85              92
# 4      Ela           75              70              78
# 5     Femi           80              78              85
# 6    Grace           68              60              70
# 7   Hassan           88              85              90
# 8      Evy           72              74              76
# 9     John           78              76              80

# %%
df.set_index("students").plot(kind="line")
plt.title("Line Chart of Scores")
plt.xlabel("Students")
plt.ylabel("Scores")
plt.show()

# %%
df.set_index("students"). plot(kind="bar")
plt.title("Students Scores")
plt.xlabel("Students")
plt.ylabel("Scores")
plt.show()

# %%
df.set_index("students")
plt.pie(math_scores, labels=students, autopct='%1.1f%%')
plt.title("Math Score Distribution")
plt.show()

# %% [markdown]
# This charts shows most students performed well in all subjects.David has the highest scores especially in science
# The line and bar charts help compair students scores,while the pie chart shows how math scores are distributed

# %% [markdown]
# Name: Yenle Nsarnaan Istifanus
# Mat No:UJ/2025/CP/0257
# Programme:Data science
# Department: computer science
# Week:7
